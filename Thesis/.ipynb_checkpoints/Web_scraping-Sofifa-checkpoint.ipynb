# %%
import requests
from bs4 import BeautifulSoup as bts
import pandas as pd
import re
import numpy as np
import time

# %%
def getAndParseURL(url):
    result = requests.get(url, headers={"User-Agent":"Mozilla/5.0"}) # Safari/537.36. Chrome/103.0.0.0
    soup = bts(result.text, "html.parser")
    return soup

# %%
pages = ["https://sofifa.com/players?&showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gd&showCol%5B%5D=gh&showCol%5B%5D=gc&showCol%5B%5D=gp&showCol%5B%5D=gr&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=bt&showCol%5B%5D=hc&showCol%5B%5D=pac&showCol%5B%5D=sho&showCol%5B%5D=tc&showCol%5B%5D=ps1&showCol%5B%5D=t2&showCol%5B%5D=t1&showCol%5B%5D=ps2&showCol%5B%5D=phy&showCol%5B%5D=def&showCol%5B%5D=dri&showCol%5B%5D=pas"]
for page in range(0,3060,60):
    pages.append("https://sofifa.com/players?&showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gd&showCol%5B%5D=gh&showCol%5B%5D=gc&showCol%5B%5D=gp&showCol%5B%5D=gr&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=bt&showCol%5B%5D=hc&showCol%5B%5D=pac&showCol%5B%5D=sho&showCol%5B%5D=tc&showCol%5B%5D=ps1&showCol%5B%5D=t2&showCol%5B%5D=t1&showCol%5B%5D=ps2&showCol%5B%5D=phy&showCol%5B%5D=def&showCol%5B%5D=dri&showCol%5B%5D=pas"+str(page))
    
pages
# Out:
# ['https://sofifa.com/players?&showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gd&showCol%5B%5D=gh&showCol%5B%5D=gc&showCol%5B%5D=gp&showCol%5B%5D=gr&showCol%5B%5D=tt
# ...

# %%
players = []
for page in pages:
    html = getAndParseURL(page)
    table = html.find("table")
    for row in table.find_all("tr")[1:]:
        cols = row.find_all("td")
        player = {"name": cols[1].get_text().strip()} # Oyuncunun adını al ve dictionary olarak tut
        for col in cols[2:]: # Oyuncunun adından sonraki tüm sütunları dolaş
            header = table.find_all("th")[cols.index(col)].get_text().strip() # Sütun başlığını al
            player[header] = col.get_text().strip() # Sütun değerini al ve oyuncu bilgilerine ekle
        players.append(player)
    time.sleep(1)

# %%
players
# Out:
# [{'name': 'Gonçalo Inácio CB LB CDM',
#   'Age': '21',
#   'Overall rating': '80',
#   'Potential': '87',
#   'Team & Contract': 'Sporting CP\n2019 ~ 2027',
#   'ID': '257179',
#   'Height': '185cm / 6\'1"',
#   'Weight': '78kg / 172lbs',
#   'foot': 'Left',
#   'Best overall': '82',
#   'Best position': 'CB',
#   'Growth': '7',
#   'Joined': 'Jul 1, 2019',
#   'Loan date end': 'N/A',
#   'Value': '€40M',
#   'Wage': '€12K',
#   'Release clause': '€88M',
#   'Total attacking': '261',
#   'Crossing': '30',
#   'Finishing': '23',
#   'Heading accuracy': '84+2',
#   'Short passing': '79',
#   'Volleys': '45',
#   'Total skill': '283',
#   'Dribbling': '69+6',
#   'Curve': '29',
#   'FK Accuracy': '27',
#   'Long passing': '85+3',
#   'Ball control': '73',
#   'Total movement': '364',
#   'Acceleration': '78',
#   'Sprint speed': '81',
#   'Agility': '73',
#   'Reactions': '77',
#   'Balance': '55',
#   'Total power': '336',
#   'Shot power': '67',
#   'Jumping': '84',
# ...

# %%
df = pd.DataFrame(players)

# %%
df['Value']
# Out:
# 0         €40M
# 1        €4.7M
# 2        €9.5M
# 3         €17M
# 4       €45.5M
#          ...
# 3115     €2.3M
# 3116    €71.5M
# 3117      €23M
# 3118      €21M
# 3119      €31M
# Name: Value, Length: 3120, dtype: object

# %%
df.to_csv('players_all2.csv', index=False)

# %%
df.head()
# Out:
#                        name Age Overall rating Potential  \
# 0  Gonçalo Inácio CB LB CDM  21             80        87
# 1         K. Páez CAM CF RW  16             71        87
# 2         A. Grønbæk CAM CM  22             74        82
# 3      M. Tillman CAM CM LW  21             76        84
# 4            Sávio LM CF LW  19             80        88
#
#                         Team & Contract      ID         Height         Weight  \
# 0              Sporting CP\n2019 ~ 2027  257179   185cm / 6'1"  78kg / 172lbs
# 1  Independiente del Valle\n2023 ~ 2025  274559  177cm / 5'10"  71kg / 157lbs
# 2             Bodø / Glimt\n2022 ~ 2028  256949   176cm / 5'9"  65kg / 143lbs
# 3             PSV\nJun 30, 2024 On loan  256853   187cm / 6'2"  71kg / 157lbs
# 4          Girona\nJun 30, 2024 On loan  270409   176cm / 5'9"  71kg / 157lbs
#
#     foot Best overall  ... Shooting / Handling Passing / Kicking  \
# 0   Left           82  ...                  37                64
# ...
