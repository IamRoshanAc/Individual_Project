# %%
import requests
from bs4 import BeautifulSoup as bts
import pandas as pd
import re
import numpy as np
import time

# %%
def getAndParseURL(url):
    result = requests.get(url, headers={"User-Agent":"Mozilla/5.0"}) # Safari/537.36. Chrome/103.0.0.0
    soup = bts(result.text, "html.parser")
    return soup

# %%
pages = ["https://sofifa.com/?&showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gd&showCol%5B%5D=gh&showCol%5B%5D=gc&showCol%5B%5D=gp&showCol%5B%5D=gr&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=bt&showCol%5B%5D=hc&showCol%5B%5D=pac&showCol%5B%5D=sho&showCol%5B%5D=pas&showCol%5B%5D=dri&showCol%5B%5D=def&showCol%5B%5D=phy&showCol%5B%5D=t1&showCol%5B%5D=t2&showCol%5B%5D=ps1&showCol%5B%5D=ps2&showCol%5B%5D=tc"]
for page in range(0,1,1):
    pages.append("https://sofifa.com/?&showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gd&showCol%5B%5D=gh&showCol%5B%5D=gc&showCol%5B%5D=gp&showCol%5B%5D=gr&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=bt&showCol%5B%5D=hc&showCol%5B%5D=pac&showCol%5B%5D=sho&showCol%5B%5D=pas&showCol%5B%5D=dri&showCol%5B%5D=def&showCol%5B%5D=phy&showCol%5B%5D=t1&showCol%5B%5D=t2&showCol%5B%5D=ps1&showCol%5B%5D=ps2&showCol%5B%5D=tc"+str(page))
    
pages
# Out:
# ['https://sofifa.com/?&showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gd&showCol%5B%5D=gh&showCol%5B%5D=gc&showCol%5B%5D=gp&showCol%5B%5D=gr&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=bt&showCol%5B%5D=hc&showCol%5B%5D=pac&showCol%5B%5D=sho&showCol%5B%5D=pas&showCol%5B%5D=dri&showCol%5B%5D=def&showCol%5B%5D=phy&showCol%5B%5D=t1&showCol%5B%5D=t2&showCol%5B%5D=ps1&showCol%5B%5D=ps2&showCol%5B%5D=tc',
#  'https://sofifa.com/?&showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tg&showCol%5B%5D=gd&showCol%5B%5D=gh&showCol%5B%5D=gc&showCol%5B%5D=gp&showCol%5B%5D=gr&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=bt&showCol%5B%5D=hc&showCol%5B%5D=pac&showCol%5B%5D=sho&showCol%5B%5D=pas&showCol%5B%5D=dri&showCol%5B%5D=def&showCol%5B%5D=phy&showCol%5B%5D=t1&showCol%5B%5D=t2&showCol%5B%5D=ps1&showCol%5B%5D=ps2&showCol%5B%5D=tc0']

# %%
players = []
for page in pages:
    html = getAndParseURL(page)
    table = html.find("table")
    for row in table.find_all("tr")[1:]:
        cols = row.find_all("td")
        player = {"name": cols[1].get_text().strip()} # Oyuncunun adını al ve dictionary olarak tut
        for col in cols[2:]: # Oyuncunun adından sonraki tüm sütunları dolaş
            header = table.find_all("th")[cols.index(col)].get_text().strip() # Sütun başlığını al
            player[header] = col.get_text().strip() # Sütun değerini al ve oyuncu bilgilerine ekle
        players.append(player)
    time.sleep(1)

# %%
players
# Out:
# [{'name': 'A. Wharton CDM CM',
#   'Age': '19',
#   'Overall rating': '74',
#   'Potential': '85',
#   'Team & Contract': 'Crystal Palace\n2024 ~ 2029',
#   'ID': '259240',
#   'Height': '182cm / 6\'0"',
#   'Weight': '70kg / 154lbs',
#   'foot': 'Left',
#   'Best overall': '76',
#   'Best position': 'CM',
#   'Growth': '11',
#   'Joined': 'Feb 1, 2024',
#   'Loan date end': 'N/A',
#   'Value': '€8.5M',
#   'Wage': '€16K',
#   'Release clause': '€17.9M',
#   'Total attacking': '317',
#   'Crossing': '66',
#   'Finishing': '59',
#   'Heading accuracy': '62',
#   'Short passing': '80',
#   'Volleys': '50',
#   'Total skill': '354',
#   'Dribbling': '74',
#   'Curve': '67',
#   'FK Accuracy': '58',
#   'Long passing': '77',
#   'Ball control': '78',
#   'Total movement': '362',
#   'Acceleration': '72',
#   'Sprint speed': '63',
#   'Agility': '74-2',
#   'Reactions': '71',
#   'Balance': '82',
#   'Total power': '343',
#   'Shot power': '66',
#   'Jumping': '73',
#   'Stamina': '73',
#   'Strength': '68',
#   'Long shots': '63',
#   'Total mentality': '328',
#   'Aggression': '72',
#   'Interceptions': '63',
#   'Att. Position': '62',
#   'Vision': '78',
#   'Penalties': '53',
#   'Composure': '80',
#   'Total defending': '211',
#   'Defensive awareness': '65',
#   'Standing tackle': '74',
#   'Sliding tackle': '72',
#   'Total goalkeeping': '47',
#   'GK Diving': '5',
#   'GK Handling': '11',
#   'GK Kicking': '13',
#   'GK Positioning': '6',
#   'GK Reflexes': '12',
#   'Total stats': '1962',
#   'Base stats': '417',
#   'Weak foot': '4',
#   'Skill moves': '3',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Normal (170-185)',
#   'Real face': 'No',
#   'Pace / Diving': '67',
#   'Shooting / Handling': '61',
#   'Passing / Kicking': '75',
#   'Dribbling / Reflexes': '76',
#   'Defending / Pace': '68',
#   'Physical / Positioning': '70',
#   'Traits': '',
#   'PlayStyles': 'Incisive Pass\u2003Slide Tackle\u2003Press Proven',
#   'PlayStyles +': '',
#   'Number of playstyles': '3',
#   '': ''},
#  {'name': 'Gabriel Sara CM CDM RM',
#   'Age': '24',
#   'Overall rating': '76',
#   'Potential': '82',
#   'Team & Contract': 'Norwich City\n2022 ~ 2026',
#   'ID': '270571',
#   'Height': '177cm / 5\'10"',
#   'Weight': '79kg / 174lbs',
#   'foot': 'Left',
#   'Best overall': '78',
#   'Best position': 'CAM',
#   'Growth': '6',
#   'Joined': 'Jul 15, 2022',
#   'Loan date end': 'N/A',
#   'Value': '€12M',
#   'Wage': '€30K',
#   'Release clause': '€25.2M',
#   'Total attacking': '359',
#   'Crossing': '73',
#   'Finishing': '72',
#   'Heading accuracy': '68',
#   'Short passing': '79',
#   'Volleys': '67',
#   'Total skill': '383',
#   'Dribbling': '75',
#   'Curve': '77',
#   'FK Accuracy': '76',
#   'Long passing': '78',
#   'Ball control': '77',
#   'Total movement': '371',
#   'Acceleration': '74',
#   'Sprint speed': '75',
#   'Agility': '71',
#   'Reactions': '75',
#   'Balance': '76',
#   'Total power': '403',
#   'Shot power': '86',
#   'Jumping': '81',
#   'Stamina': '83',
#   'Strength': '79',
#   'Long shots': '74',
#   'Total mentality': '338',
#   'Aggression': '77',
#   'Interceptions': '55',
#   'Att. Position': '77',
#   'Vision': '79',
#   'Penalties': '50',
#   'Composure': '78',
#   'Total defending': '171',
#   'Defensive awareness': '57',
#   'Standing tackle': '62',
#   'Sliding tackle': '52',
#   'Total goalkeeping': '53',
#   'GK Diving': '14',
#   'GK Handling': '14',
#   'GK Kicking': '10',
#   'GK Positioning': '6',
#   'GK Reflexes': '9',
#   'Total stats': '2078',
#   'Base stats': '440',
#   'Weak foot': '3',
#   'Skill moves': '3',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Stocky (170-185)',
#   'Real face': 'No',
#   'Pace / Diving': '75',
#   'Shooting / Handling': '74',
#   'Passing / Kicking': '77',
#   'Dribbling / Reflexes': '75',
#   'Defending / Pace': '59',
#   'Physical / Positioning': '80',
#   'Traits': '',
#   'PlayStyles': 'Power Shot\u2003Flair',
#   'PlayStyles +': '',
#   'Number of playstyles': '2',
#   '': ''},
#  {'name': 'K. Páez CAM CF RW',
#   'Age': '16',
#   'Overall rating': '71',
#   'Potential': '87',
#   'Team & Contract': 'Independiente del Valle\n2023 ~ 2025',
#   'ID': '274559',
#   'Height': '177cm / 5\'10"',
#   'Weight': '71kg / 157lbs',
#   'foot': 'Left',
#   'Best overall': '73',
#   'Best position': 'CAM',
#   'Growth': '16',
#   'Joined': 'Jan 1, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€4.7M',
#   'Wage': '€500',
#   'Release clause': '€13.3M',
#   'Total attacking': '295',
#   'Crossing': '61',
#   'Finishing': '68',
#   'Heading accuracy': '48',
#   'Short passing': '74',
#   'Volleys': '44',
#   'Total skill': '343',
#   'Dribbling': '73',
#   'Curve': '73',
#   'FK Accuracy': '60',
#   'Long passing': '66',
#   'Ball control': '71',
#   'Total movement': '374',
#   'Acceleration': '77',
#   'Sprint speed': '81',
#   'Agility': '82',
#   'Reactions': '59',
#   'Balance': '75',
#   'Total power': '308',
#   'Shot power': '65',
#   'Jumping': '58',
#   'Stamina': '65',
#   'Strength': '49',
#   'Long shots': '71',
#   'Total mentality': '294',
#   'Aggression': '44',
#   'Interceptions': '56',
#   'Att. Position': '72',
#   'Vision': '71',
#   'Penalties': '51',
#   'Composure': '52',
#   'Total defending': '117',
#   'Defensive awareness': '34',
#   'Standing tackle': '42',
#   'Sliding tackle': '41',
#   'Total goalkeeping': '51',
#   'GK Diving': '10',
#   'GK Handling': '11',
#   'GK Kicking': '9',
#   'GK Positioning': '15',
#   'GK Reflexes': '6',
#   'Total stats': '1782',
#   'Base stats': '381',
#   'Weak foot': '3',
#   'Skill moves': '4',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Lean (170-185)',
#   'Real face': 'No',
#   'Pace / Diving': '79',
#   'Shooting / Handling': '66',
#   'Passing / Kicking': '69',
#   'Dribbling / Reflexes': '72',
#   'Defending / Pace': '43',
#   'Physical / Positioning': '52',
#   'Traits': '',
#   'PlayStyles': 'Pinged Pass\u2003Technical\u2003First Touch\u2003Trickster',
#   'PlayStyles +': '',
#   'Number of playstyles': '4',
#   '': ''},
#  {'name': '10\xa0M. Dabo LF',
#   'Age': '23',
#   'Overall rating': '56',
#   'Potential': '65',
#   'Team & Contract': 'Senegal\nFree',
#   'ID': '177703',
#   'Height': '186cm / 6\'1"',
#   'Weight': '77kg / 170lbs',
#   'foot': 'Left',
#   'Best overall': '59',
#   'Best position': 'LF',
#   'Growth': '9',
#   'Joined': 'N/A',
#   'Loan date end': 'N/A',
#   'Value': '€0',
#   'Wage': '€0',
#   'Release clause': '€0',
#   'Total attacking': '191',
#   'Crossing': '37',
#   'Finishing': '62',
#   'Heading accuracy': '49',
#   'Short passing': '43',
#   'Volleys': '0',
#   'Total skill': '194',
#   'Dribbling': '63',
#   'Curve': '0',
#   'FK Accuracy': '45',
#   'Long passing': '41',
#   'Ball control': '45',
#   'Total movement': '198',
#   'Acceleration': '65',
#   'Sprint speed': '70',
#   'Agility': '0',
#   'Reactions': '63',
#   'Balance': '0',
#   'Total power': '210',
#   'Shot power': '59',
#   'Jumping': '0',
#   'Stamina': '55',
#   'Strength': '44',
#   'Long shots': '52',
#   'Total mentality': '157',
#   'Aggression': '51',
#   'Interceptions': '32',
#   'Att. Position': '38',
#   'Vision': '0',
#   'Penalties': '36',
#   'Composure': '0',
#   'Total defending': '40',
#   'Defensive awareness': '20',
#   'Standing tackle': '20',
#   'Sliding tackle': '0',
#   'Total goalkeeping': '62',
#   'GK Diving': '2',
#   'GK Handling': '20',
#   'GK Kicking': '41',
#   'GK Positioning': '20',
#   'GK Reflexes': '20',
#   'Total stats': '1052',
#   'Base stats': '296',
#   'Weak foot': '3',
#   'Skill moves': '1',
#   'Attacking work rate': 'N/A',
#   'Defensive work rate': 'N/A',
#   'International reputation': '1',
#   'Body type': 'PLAYER_BODY_TYPE_',
#   'Real face': 'Yes',
#   'Pace / Diving': '68',
#   'Shooting / Handling': '56',
#   'Passing / Kicking': '41',
#   'Dribbling / Reflexes': '57',
#   'Defending / Pace': '25',
#   'Physical / Positioning': '49',
#   'Traits': '',
#   'PlayStyles': '',
#   'PlayStyles +': '',
#   'Number of playstyles': '0',
#   '': ''},
#  {'name': 'C. Palmer RM RW CAM',
#   'Age': '21',
#   'Overall rating': '79',
#   'Potential': '87',
#   'Team & Contract': 'Chelsea\n2023 ~ 2030',
#   'ID': '257534',
#   'Height': '189cm / 6\'2"',
#   'Weight': '74kg / 163lbs',
#   'foot': 'Left',
#   'Best overall': '82',
#   'Best position': 'CAM',
#   'Growth': '8',
#   'Joined': 'Sep 1, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€39.5M',
#   'Wage': '€76K',
#   'Release clause': '€83M',
#   'Total attacking': '343',
#   'Crossing': '70',
#   'Finishing': '80',
#   'Heading accuracy': '48',
#   'Short passing': '82',
#   'Volleys': '63',
#   'Total skill': '378',
#   'Dribbling': '81',
#   'Curve': '77',
#   'FK Accuracy': '66+2',
#   'Long passing': '71',
#   'Ball control': '83',
#   'Total movement': '377',
#   'Acceleration': '72',
#   'Sprint speed': '77',
#   'Agility': '78',
#   'Reactions': '80',
#   'Balance': '70',
#   'Total power': '342',
#   'Shot power': '75',
#   'Jumping': '62',
#   'Stamina': '75',
#   'Strength': '58',
#   'Long shots': '72',
#   'Total mentality': '347',
#   'Aggression': '57',
#   'Interceptions': '43',
#   'Att. Position': '80',
#   'Vision': '82',
#   'Penalties': '85',
#   'Composure': '84',
#   'Total defending': '144',
#   'Defensive awareness': '47',
#   'Standing tackle': '52',
#   'Sliding tackle': '45',
#   'Total goalkeeping': '51',
#   'GK Diving': '7',
#   'GK Handling': '6',
#   'GK Kicking': '10',
#   'GK Positioning': '14',
#   'GK Reflexes': '14',
#   'Total stats': '1982',
#   'Base stats': '420',
#   'Weak foot': '3',
#   'Skill moves': '4',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Lean (185+)',
#   'Real face': 'Yes',
#   'Pace / Diving': '75',
#   'Shooting / Handling': '77',
#   'Passing / Kicking': '77',
#   'Dribbling / Reflexes': '81',
#   'Defending / Pace': '48',
#   'Physical / Positioning': '62',
#   'Traits': '',
#   'PlayStyles': 'Technical',
#   'PlayStyles +': '',
#   'Number of playstyles': '1',
#   '': ''},
#  {'name': 'A. Gray CM RB CDM',
#   'Age': '17',
#   'Overall rating': '72',
#   'Potential': '86',
#   'Team & Contract': 'Leeds United\n2021 ~ 2028',
#   'ID': '270208',
#   'Height': '187cm / 6\'2"',
#   'Weight': '70kg / 154lbs',
#   'foot': 'Right',
#   'Best overall': '74',
#   'Best position': 'CM',
#   'Growth': '14',
#   'Joined': 'Dec 18, 2021',
#   'Loan date end': 'N/A',
#   'Value': '€5.5M',
#   'Wage': '€4K',
#   'Release clause': '€13.9M',
#   'Total attacking': '321',
#   'Crossing': '67',
#   'Finishing': '59',
#   'Heading accuracy': '65',
#   'Short passing': '75',
#   'Volleys': '55',
#   'Total skill': '336',
#   'Dribbling': '74',
#   'Curve': '60',
#   'FK Accuracy': '55',
#   'Long passing': '73',
#   'Ball control': '74',
#   'Total movement': '367',
#   'Acceleration': '74',
#   'Sprint speed': '77',
#   'Agility': '72',
#   'Reactions': '72',
#   'Balance': '72',
#   'Total power': '342',
#   'Shot power': '62',
#   'Jumping': '75',
#   'Stamina': '75',
#   'Strength': '70',
#   'Long shots': '60',
#   'Total mentality': '336',
#   'Aggression': '71',
#   'Interceptions': '70',
#   'Att. Position': '68',
#   'Vision': '70',
#   'Penalties': '57',
#   'Composure': '75',
#   'Total defending': '210',
#   'Defensive awareness': '70',
#   'Standing tackle': '70',
#   'Sliding tackle': '70',
#   'Total goalkeeping': '51',
#   'GK Diving': '15',
#   'GK Handling': '12',
#   'GK Kicking': '13',
#   'GK Positioning': '6',
#   'GK Reflexes': '5',
#   'Total stats': '1963',
#   'Base stats': '422',
#   'Weak foot': '4',
#   'Skill moves': '2',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'High',
#   'International reputation': '1',
#   'Body type': 'Lean (185+)',
#   'Real face': 'No',
#   'Pace / Diving': '76',
#   'Shooting / Handling': '60',
#   'Passing / Kicking': '70',
#   'Dribbling / Reflexes': '74',
#   'Defending / Pace': '70',
#   'Physical / Positioning': '72',
#   'Traits': '',
#   'PlayStyles': 'Long Ball Pass',
#   'PlayStyles +': '',
#   'Number of playstyles': '1',
#   '': ''},
#  {'name': 'M. Olise RM RW CAM',
#   'Age': '21',
#   'Overall rating': '80',
#   'Potential': '88',
#   'Team & Contract': 'Crystal Palace\n2021 ~ 2027',
#   'ID': '247827',
#   'Height': '184cm / 6\'0"',
#   'Weight': '73kg / 161lbs',
#   'foot': 'Left',
#   'Best overall': '82',
#   'Best position': 'CAM',
#   'Growth': '8',
#   'Joined': 'Jul 8, 2021',
#   'Loan date end': 'N/A',
#   'Value': '€47.5M',
#   'Wage': '€37K',
#   'Release clause': '€99.8M',
#   'Total attacking': '338',
#   'Crossing': '80',
#   'Finishing': '77',
#   'Heading accuracy': '36',
#   'Short passing': '80',
#   'Volleys': '65',
#   'Total skill': '399',
#   'Dribbling': '84',
#   'Curve': '80',
#   'FK Accuracy': '76',
#   'Long passing': '77',
#   'Ball control': '82',
#   'Total movement': '413',
#   'Acceleration': '82',
#   'Sprint speed': '79',
#   'Agility': '91',
#   'Reactions': '75',
#   'Balance': '86',
#   'Total power': '317',
#   'Shot power': '76',
#   'Jumping': '55',
#   'Stamina': '68',
#   'Strength': '46',
#   'Long shots': '72',
#   'Total mentality': '345',
#   'Aggression': '68',
#   'Interceptions': '50',
#   'Att. Position': '75',
#   'Vision': '83',
#   'Penalties': '69',
#   'Composure': '79',
#   'Total defending': '159',
#   'Defensive awareness': '52',
#   'Standing tackle': '56',
#   'Sliding tackle': '51',
#   'Total goalkeeping': '49',
#   'GK Diving': '9',
#   'GK Handling': '11',
#   'GK Kicking': '9',
#   'GK Positioning': '10',
#   'GK Reflexes': '10',
#   'Total stats': '2020',
#   'Base stats': '426',
#   'Weak foot': '2',
#   'Skill moves': '4',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Lean (170-185)',
#   'Real face': 'Yes',
#   'Pace / Diving': '80',
#   'Shooting / Handling': '75',
#   'Passing / Kicking': '80',
#   'Dribbling / Reflexes': '84',
#   'Defending / Pace': '51',
#   'Physical / Positioning': '56',
#   'Traits': '',
#   'PlayStyles': 'Finesse Shot\u2003Dead Ball\u2003Technical\u2003Flair\u2003Trivela',
#   'PlayStyles +': '',
#   'Number of playstyles': '5',
#   '': ''},
#  {'name': 'R. Calafiori CB LB',
#   'Age': '21',
#   'Overall rating': '75',
#   'Potential': '84',
#   'Team & Contract': 'Bologna\n2023 ~ 2027',
#   'ID': '257711',
#   'Height': '188cm / 6\'2"',
#   'Weight': '86kg / 190lbs',
#   'foot': 'Left',
#   'Best overall': '77',
#   'Best position': 'CB',
#   'Growth': '9',
#   'Joined': 'Aug 31, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€12M',
#   'Wage': '€19K',
#   'Release clause': '€22.8M',
#   'Total attacking': '299',
#   'Crossing': '74',
#   'Finishing': '28',
#   'Heading accuracy': '69',
#   'Short passing': '75',
#   'Volleys': '53',
#   'Total skill': '347',
#   'Dribbling': '69',
#   'Curve': '72',
#   'FK Accuracy': '65',
#   'Long passing': '67',
#   'Ball control': '74',
#   'Total movement': '354',
#   'Acceleration': '69',
#   'Sprint speed': '73',
#   'Agility': '70',
#   'Reactions': '73',
#   'Balance': '69',
#   'Total power': '380',
#   'Shot power': '74',
#   'Jumping': '79',
#   'Stamina': '76',
#   'Strength': '79',
#   'Long shots': '72',
#   'Total mentality': '318',
#   'Aggression': '77',
#   'Interceptions': '74',
#   'Att. Position': '62',
#   'Vision': '56',
#   'Penalties': '49',
#   'Composure': '67',
#   'Total defending': '228',
#   'Defensive awareness': '75',
#   'Standing tackle': '77',
#   'Sliding tackle': '76',
#   'Total goalkeeping': '42',
#   'GK Diving': '9',
#   'GK Handling': '11',
#   'GK Kicking': '5',
#   'GK Positioning': '6',
#   'GK Reflexes': '11',
#   'Total stats': '1968',
#   'Base stats': '414',
#   'Weak foot': '4',
#   'Skill moves': '3',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Normal (185+)',
#   'Real face': 'No',
#   'Pace / Diving': '71',
#   'Shooting / Handling': '50',
#   'Passing / Kicking': '69',
#   'Dribbling / Reflexes': '71',
#   'Defending / Pace': '75',
#   'Physical / Positioning': '78',
#   'Traits': '',
#   'PlayStyles': 'Intercept\u2003Anticipate\u2003Aerial',
#   'PlayStyles +': '',
#   'Number of playstyles': '3',
#   '': ''},
#  {'name': 'B. Šeško ST',
#   'Age': '20',
#   'Overall rating': '78+1',
#   'Potential': '87+1',
#   'Team & Contract': 'RB Leipzig\n2023 ~ 2028',
#   'ID': '260592',
#   'Height': '195cm / 6\'5"',
#   'Weight': '85kg / 187lbs',
#   'foot': 'Right',
#   'Best overall': '80',
#   'Best position': 'ST',
#   'Growth': '9',
#   'Joined': 'Jul 1, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€31M',
#   'Wage': '€41K',
#   'Release clause': '€58.9M',
#   'Total attacking': '358',
#   'Crossing': '55',
#   'Finishing': '81+2',
#   'Heading accuracy': '79+2',
#   'Short passing': '71+2',
#   'Volleys': '72+1',
#   'Total skill': '322',
#   'Dribbling': '76+1',
#   'Curve': '59',
#   'FK Accuracy': '56',
#   'Long passing': '53+1',
#   'Ball control': '78+1',
#   'Total movement': '379',
#   'Acceleration': '79',
#   'Sprint speed': '86',
#   'Agility': '74',
#   'Reactions': '71+1',
#   'Balance': '69',
#   'Total power': '399',
#   'Shot power': '79',
#   'Jumping': '92+1',
#   'Stamina': '74',
#   'Strength': '83',
#   'Long shots': '71',
#   'Total mentality': '298',
#   'Aggression': '62',
#   'Interceptions': '35+3',
#   'Att. Position': '79+2',
#   'Vision': '61',
#   'Penalties': '61',
#   'Composure': '75+1',
#   'Total defending': '122',
#   'Defensive awareness': '45+3',
#   'Standing tackle': '42',
#   'Sliding tackle': '35',
#   'Total goalkeeping': '43',
#   'GK Diving': '10',
#   'GK Handling': '8',
#   'GK Kicking': '5',
#   'GK Positioning': '14',
#   'GK Reflexes': '6',
#   'Total stats': '1921',
#   'Base stats': '420',
#   'Weak foot': '4',
#   'Skill moves': '3',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Lean (185+)',
#   'Real face': 'No',
#   'Pace / Diving': '83',
#   'Shooting / Handling': '77',
#   'Passing / Kicking': '62',
#   'Dribbling / Reflexes': '76',
#   'Defending / Pace': '45',
#   'Physical / Positioning': '77',
#   'Traits': '',
#   'PlayStyles': 'Power Shot\u2003Technical\u2003Flair',
#   'PlayStyles +': '',
#   'Number of playstyles': '3',
#   '': ''},
#  {'name': 'A. Güler CAM RM',
#   'Age': '18',
#   'Overall rating': '77',
#   'Potential': '88',
#   'Team & Contract': 'Real Madrid\n2023 ~ 2029',
#   'ID': '264309',
#   'Height': '175cm / 5\'9"',
#   'Weight': '70kg / 154lbs',
#   'foot': 'Left',
#   'Best overall': '79',
#   'Best position': 'CAM',
#   'Growth': '11',
#   'Joined': 'Jul 6, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€22M',
#   'Wage': '€41K',
#   'Release clause': '€49.5M',
#   'Total attacking': '340',
#   'Crossing': '80',
#   'Finishing': '68',
#   'Heading accuracy': '41',
#   'Short passing': '81',
#   'Volleys': '70',
#   'Total skill': '403',
#   'Dribbling': '83',
#   'Curve': '84',
#   'FK Accuracy': '76',
#   'Long passing': '79',
#   'Ball control': '81',
#   'Total movement': '380',
#   'Acceleration': '75',
#   'Sprint speed': '69',
#   'Agility': '82',
#   'Reactions': '69',
#   'Balance': '85',
#   'Total power': '308',
#   'Shot power': '72',
#   'Jumping': '50',
#   'Stamina': '70',
#   'Strength': '43',
#   'Long shots': '73',
#   'Total mentality': '316',
#   'Aggression': '42',
#   'Interceptions': '55',
#   'Att. Position': '68',
#   'Vision': '80',
#   'Penalties': '71',
#   'Composure': '77',
#   'Total defending': '155',
#   'Defensive awareness': '52',
#   'Standing tackle': '57',
#   'Sliding tackle': '46',
#   'Total goalkeeping': '58',
#   'GK Diving': '13',
#   'GK Handling': '10',
#   'GK Kicking': '11',
#   'GK Positioning': '14',
#   'GK Reflexes': '10',
#   'Total stats': '1960',
#   'Base stats': '405',
#   'Weak foot': '3',
#   'Skill moves': '4',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Lean (170-185)',
#   'Real face': 'Yes',
#   'Pace / Diving': '72',
#   'Shooting / Handling': '70',
#   'Passing / Kicking': '80',
#   'Dribbling / Reflexes': '81',
#   'Defending / Pace': '52',
#   'Physical / Positioning': '50',
#   'Traits': '',
#   'PlayStyles': 'Finesse Shot\u2003Incisive Pass\u2003Long Ball Pass\u2003Whipped Cross\u2003Technical\u2003Flair',
#   'PlayStyles +': '',
#   'Number of playstyles': '6',
#   '': ''},
#  {'name': 'J. Bellingham CM CAM ST',
#   'Age': '17',
#   'Overall rating': '66',
#   'Potential': '82',
#   'Team & Contract': 'Sunderland\n2023 ~ 2028',
#   'ID': '270964',
#   'Height': '191cm / 6\'3"',
#   'Weight': '75kg / 165lbs',
#   'foot': 'Right',
#   'Best overall': '68',
#   'Best position': 'CAM',
#   'Growth': '16',
#   'Joined': 'Jun 24, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€2.1M',
#   'Wage': '€1K',
#   'Release clause': '€5.3M',
#   'Total attacking': '292',
#   'Crossing': '53+2',
#   'Finishing': '61+5',
#   'Heading accuracy': '64',
#   'Short passing': '67',
#   'Volleys': '47',
#   'Total skill': '303',
#   'Dribbling': '69',
#   'Curve': '55',
#   'FK Accuracy': '44',
#   'Long passing': '65',
#   'Ball control': '70',
#   'Total movement': '335',
#   'Acceleration': '65-3',
#   'Sprint speed': '71-1',
#   'Agility': '68',
#   'Reactions': '61',
#   'Balance': '70',
#   'Total power': '322',
#   'Shot power': '59+2',
#   'Jumping': '69-1',
#   'Stamina': '73+4',
#   'Strength': '63',
#   'Long shots': '58+2',
#   'Total mentality': '296',
#   'Aggression': '56',
#   'Interceptions': '64',
#   'Att. Position': '65',
#   'Vision': '66',
#   'Penalties': '45',
#   'Composure': '68+2',
#   'Total defending': '187',
#   'Defensive awareness': '61',
#   'Standing tackle': '66',
#   'Sliding tackle': '60',
#   'Total goalkeeping': '59',
#   'GK Diving': '10',
#   'GK Handling': '10',
#   'GK Kicking': '13',
#   'GK Positioning': '15',
#   'GK Reflexes': '11',
#   'Total stats': '1794',
#   'Base stats': '385',
#   'Weak foot': '3',
#   'Skill moves': '3',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'High',
#   'International reputation': '1',
#   'Body type': 'Lean (185+)',
#   'Real face': 'No',
#   'Pace / Diving': '68',
#   'Shooting / Handling': '59',
#   'Passing / Kicking': '62',
#   'Dribbling / Reflexes': '69',
#   'Defending / Pace': '63',
#   'Physical / Positioning': '64',
#   'Traits': '',
#   'PlayStyles': '',
#   'PlayStyles +': '',
#   'Number of playstyles': '0',
#   '': ''},
#  {'name': 'K. Havertz CAM CM ST',
#   'Age': '24',
#   'Overall rating': '82',
#   'Potential': '87',
#   'Team & Contract': 'Arsenal\n2023 ~ 2028',
#   'ID': '235790',
#   'Height': '193cm / 6\'4"',
#   'Weight': '82kg / 181lbs',
#   'foot': 'Left',
#   'Best overall': '85',
#   'Best position': 'CAM',
#   'Growth': '5',
#   'Joined': 'Jun 28, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€46M',
#   'Wage': '€110K',
#   'Release clause': '€88.6M',
#   'Total attacking': '404',
#   'Crossing': '74',
#   'Finishing': '83',
#   'Heading accuracy': '83',
#   'Short passing': '84',
#   'Volleys': '80',
#   'Total skill': '385',
#   'Dribbling': '84',
#   'Curve': '84',
#   'FK Accuracy': '53',
#   'Long passing': '79',
#   'Ball control': '85',
#   'Total movement': '382',
#   'Acceleration': '75',
#   'Sprint speed': '81',
#   'Agility': '75',
#   'Reactions': '83',
#   'Balance': '68',
#   'Total power': '385',
#   'Shot power': '76',
#   'Jumping': '84',
#   'Stamina': '77',
#   'Strength': '70',
#   'Long shots': '78',
#   'Total mentality': '347',
#   'Aggression': '56',
#   'Interceptions': '43',
#   'Att. Position': '84',
#   'Vision': '81',
#   'Penalties': '83',
#   'Composure': '84',
#   'Total defending': '133',
#   'Defensive awareness': '45',
#   'Standing tackle': '47',
#   'Sliding tackle': '41',
#   'Total goalkeeping': '47',
#   'GK Diving': '6',
#   'GK Handling': '8',
#   'GK Kicking': '11',
#   'GK Positioning': '10',
#   'GK Reflexes': '12',
#   'Total stats': '2083',
#   'Base stats': '440',
#   'Weak foot': '4',
#   'Skill moves': '4',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'Medium',
#   'International reputation': '3',
#   'Body type': 'Unique',
#   'Real face': 'Yes',
#   'Pace / Diving': '78',
#   'Shooting / Handling': '81',
#   'Passing / Kicking': '79',
#   'Dribbling / Reflexes': '83',
#   'Defending / Pace': '49',
#   'Physical / Positioning': '70',
#   'Traits': '',
#   'PlayStyles': 'Chip Shot\u2003Technical\u2003First Touch\u2003Trivela',
#   'PlayStyles +': '',
#   'Number of playstyles': '4',
#   '': ''},
#  {'name': 'M. Beier ST LM RM',
#   'Age': '20',
#   'Overall rating': '75',
#   'Potential': '84',
#   'Team & Contract': 'TSG Hoffenheim\n2019 ~ 2027',
#   'ID': '254117',
#   'Height': '185cm / 6\'1"',
#   'Weight': '72kg / 159lbs',
#   'foot': 'Right',
#   'Best overall': '77',
#   'Best position': 'ST',
#   'Growth': '9',
#   'Joined': 'Nov 1, 2019',
#   'Loan date end': 'N/A',
#   'Value': '€12.5M',
#   'Wage': '€25K',
#   'Release clause': '€23.8M',
#   'Total attacking': '330',
#   'Crossing': '55',
#   'Finishing': '78',
#   'Heading accuracy': '62',
#   'Short passing': '69',
#   'Volleys': '66',
#   'Total skill': '321',
#   'Dribbling': '78',
#   'Curve': '65',
#   'FK Accuracy': '47',
#   'Long passing': '55',
#   'Ball control': '76',
#   'Total movement': '416',
#   'Acceleration': '88',
#   'Sprint speed': '94',
#   'Agility': '82',
#   'Reactions': '75',
#   'Balance': '77',
#   'Total power': '347',
#   'Shot power': '76',
#   'Jumping': '72',
#   'Stamina': '78',
#   'Strength': '50',
#   'Long shots': '71',
#   'Total mentality': '275',
#   'Aggression': '47',
#   'Interceptions': '22',
#   'Att. Position': '78',
#   'Vision': '67',
#   'Penalties': '61',
#   'Composure': '65',
#   'Total defending': '60',
#   'Defensive awareness': '22',
#   'Standing tackle': '21',
#   'Sliding tackle': '17',
#   'Total goalkeeping': '41',
#   'GK Diving': '6',
#   'GK Handling': '8',
#   'GK Kicking': '8',
#   'GK Positioning': '6',
#   'GK Reflexes': '13',
#   'Total stats': '1790',
#   'Base stats': '388',
#   'Weak foot': '3',
#   'Skill moves': '3',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Lean (185+)',
#   'Real face': 'No',
#   'Pace / Diving': '91',
#   'Shooting / Handling': '75',
#   'Passing / Kicking': '62',
#   'Dribbling / Reflexes': '77',
#   'Defending / Pace': '25',
#   'Physical / Positioning': '58',
#   'Traits': '',
#   'PlayStyles': 'Rapid\u2003Quick Step',
#   'PlayStyles +': '',
#   'Number of playstyles': '2',
#   '': ''},
#  {'name': 'J. Hato CB LB',
#   'Age': '17',
#   'Overall rating': '73',
#   'Potential': '88',
#   'Team & Contract': 'Ajax\n2022 ~ 2028',
#   'ID': '272978',
#   'Height': '182cm / 6\'0"',
#   'Weight': '76kg / 168lbs',
#   'foot': 'Left',
#   'Best overall': '75',
#   'Best position': 'CDM',
#   'Growth': '15',
#   'Joined': 'Mar 14, 2022',
#   'Loan date end': 'N/A',
#   'Value': '€6.5M',
#   'Wage': '€550',
#   'Release clause': '€13.2M',
#   'Total attacking': '270',
#   'Crossing': '55',
#   'Finishing': '36',
#   'Heading accuracy': '67',
#   'Short passing': '77',
#   'Volleys': '35',
#   'Total skill': '299',
#   'Dribbling': '67',
#   'Curve': '54',
#   'FK Accuracy': '31',
#   'Long passing': '73',
#   'Ball control': '74',
#   'Total movement': '395',
#   'Acceleration': '82',
#   'Sprint speed': '88',
#   'Agility': '75',
#   'Reactions': '75',
#   'Balance': '75',
#   'Total power': '306',
#   'Shot power': '53',
#   'Jumping': '86',
#   'Stamina': '71',
#   'Strength': '67',
#   'Long shots': '29',
#   'Total mentality': '294',
#   'Aggression': '67',
#   'Interceptions': '77',
#   'Att. Position': '52',
#   'Vision': '64',
#   'Penalties': '34',
#   'Composure': '72',
#   'Total defending': '216',
#   'Defensive awareness': '72',
#   'Standing tackle': '74',
#   'Sliding tackle': '70',
#   'Total goalkeeping': '40',
#   'GK Diving': '8',
#   'GK Handling': '5',
#   'GK Kicking': '5',
#   'GK Positioning': '13',
#   'GK Reflexes': '9',
#   'Total stats': '1820',
#   'Base stats': '403',
#   'Weak foot': '3',
#   'Skill moves': '2',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Normal (170-185)',
#   'Real face': 'No',
#   'Pace / Diving': '85',
#   'Shooting / Handling': '39',
#   'Passing / Kicking': '66',
#   'Dribbling / Reflexes': '71',
#   'Defending / Pace': '73',
#   'Physical / Positioning': '69',
#   'Traits': '',
#   'PlayStyles': '',
#   'PlayStyles +': '',
#   'Number of playstyles': '0',
#   '': ''},
#  {'name': 'Alejandro Garnacho LM RM',
#   'Age': '19',
#   'Overall rating': '77+1',
#   'Potential': '87',
#   'Team & Contract': 'Manchester United\n2021 ~ 2028',
#   'ID': '268438',
#   'Height': '180cm / 5\'11"',
#   'Weight': '72kg / 159lbs',
#   'foot': 'Right',
#   'Best overall': '78',
#   'Best position': 'RM',
#   'Growth': '10',
#   'Joined': 'Jul 28, 2021',
#   'Loan date end': 'N/A',
#   'Value': '€23M',
#   'Wage': '€53K',
#   'Release clause': '€48.3M',
#   'Total attacking': '334',
#   'Crossing': '72+2',
#   'Finishing': '75+3',
#   'Heading accuracy': '44',
#   'Short passing': '73+1',
#   'Volleys': '70',
#   'Total skill': '348',
#   'Dribbling': '79+1',
#   'Curve': '75',
#   'FK Accuracy': '61',
#   'Long passing': '56',
#   'Ball control': '77+2',
#   'Total movement': '423',
#   'Acceleration': '88',
#   'Sprint speed': '84',
#   'Agility': '87',
#   'Reactions': '76',
#   'Balance': '88',
#   'Total power': '330',
#   'Shot power': '78',
#   'Jumping': '60+1',
#   'Stamina': '76',
#   'Strength': '47',
#   'Long shots': '69',
#   'Total mentality': '309',
#   'Aggression': '66',
#   'Interceptions': '40',
#   'Att. Position': '77',
#   'Vision': '70+1',
#   'Penalties': '56',
#   'Composure': '72',
#   'Total defending': '98',
#   'Defensive awareness': '32',
#   'Standing tackle': '37',
#   'Sliding tackle': '29',
#   'Total goalkeeping': '55',
#   'GK Diving': '6',
#   'GK Handling': '15',
#   'GK Kicking': '14',
#   'GK Positioning': '13',
#   'GK Reflexes': '7',
#   'Total stats': '1897',
#   'Base stats': '402',
#   'Weak foot': '4',
#   'Skill moves': '3',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'High',
#   'International reputation': '1',
#   'Body type': 'Lean (170-185)',
#   'Real face': 'Yes',
#   'Pace / Diving': '86',
#   'Shooting / Handling': '73',
#   'Passing / Kicking': '69',
#   'Dribbling / Reflexes': '79',
#   'Defending / Pace': '36',
#   'Physical / Positioning': '59',
#   'Traits': '',
#   'PlayStyles': 'Finesse Shot\u2003Technical\u2003Flair\u2003Quick Step',
#   'PlayStyles +': '',
#   'Number of playstyles': '4',
#   '': ''},
#  {'name': 'K. Mainoo CDM CM',
#   'Age': '18',
#   'Overall rating': '72',
#   'Potential': '87',
#   'Team & Contract': 'Manchester United\n2022 ~ 2027',
#   'ID': '269136',
#   'Height': '184cm / 6\'0"',
#   'Weight': '80kg / 176lbs',
#   'foot': 'Right',
#   'Best overall': '73',
#   'Best position': 'CAM',
#   'Growth': '15',
#   'Joined': 'May 16, 2022',
#   'Loan date end': 'N/A',
#   'Value': '€5M',
#   'Wage': '€16K',
#   'Release clause': '€12.6M',
#   'Total attacking': '308',
#   'Crossing': '54',
#   'Finishing': '60',
#   'Heading accuracy': '64',
#   'Short passing': '78',
#   'Volleys': '52',
#   'Total skill': '331',
#   'Dribbling': '79',
#   'Curve': '63',
#   'FK Accuracy': '41',
#   'Long passing': '74',
#   'Ball control': '74',
#   'Total movement': '379',
#   'Acceleration': '77',
#   'Sprint speed': '72',
#   'Agility': '78',
#   'Reactions': '68',
#   'Balance': '84',
#   'Total power': '334',
#   'Shot power': '67',
#   'Jumping': '76',
#   'Stamina': '69',
#   'Strength': '68',
#   'Long shots': '54',
#   'Total mentality': '317',
#   'Aggression': '70',
#   'Interceptions': '64',
#   'Att. Position': '63',
#   'Vision': '69',
#   'Penalties': '51',
#   'Composure': '75',
#   'Total defending': '205',
#   'Defensive awareness': '70',
#   'Standing tackle': '72',
#   'Sliding tackle': '63',
#   'Total goalkeeping': '49',
#   'GK Diving': '14',
#   'GK Handling': '11',
#   'GK Kicking': '10',
#   'GK Positioning': '5',
#   'GK Reflexes': '9',
#   'Total stats': '1923',
#   'Base stats': '416',
#   'Weak foot': '3',
#   'Skill moves': '3',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'High',
#   'International reputation': '1',
#   'Body type': 'Lean (170-185)',
#   'Real face': 'No',
#   'Pace / Diving': '74',
#   'Shooting / Handling': '60',
#   'Passing / Kicking': '68',
#   'Dribbling / Reflexes': '77',
#   'Defending / Pace': '68',
#   'Physical / Positioning': '69',
#   'Traits': '',
#   'PlayStyles': 'Long Ball Pass\u2003Press Proven\u2003Trivela',
#   'PlayStyles +': '',
#   'Number of playstyles': '3',
#   '': ''},
#  {'name': 'J. Zirkzee ST',
#   'Age': '22',
#   'Overall rating': '78',
#   'Potential': '86',
#   'Team & Contract': 'Bologna\n2022 ~ 2026',
#   'ID': '250961',
#   'Height': '193cm / 6\'4"',
#   'Weight': '89kg / 196lbs',
#   'foot': 'Right',
#   'Best overall': '81',
#   'Best position': 'CAM',
#   'Growth': '8',
#   'Joined': 'Aug 30, 2022',
#   'Loan date end': 'N/A',
#   'Value': '€32M',
#   'Wage': '€34K',
#   'Release clause': '€60.8M',
#   'Total attacking': '351',
#   'Crossing': '55',
#   'Finishing': '80',
#   'Heading accuracy': '71',
#   'Short passing': '78',
#   'Volleys': '67',
#   'Total skill': '365',
#   'Dribbling': '81',
#   'Curve': '68',
#   'FK Accuracy': '66',
#   'Long passing': '65',
#   'Ball control': '85',
#   'Total movement': '368',
#   'Acceleration': '74',
#   'Sprint speed': '76',
#   'Agility': '84',
#   'Reactions': '74',
#   'Balance': '60',
#   'Total power': '385',
#   'Shot power': '76',
#   'Jumping': '85',
#   'Stamina': '67',
#   'Strength': '81',
#   'Long shots': '76',
#   'Total mentality': '290',
#   'Aggression': '43',
#   'Interceptions': '14',
#   'Att. Position': '78',
#   'Vision': '78',
#   'Penalties': '77',
#   'Composure': '83',
#   'Total defending': '59',
#   'Defensive awareness': '20',
#   'Standing tackle': '20',
#   'Sliding tackle': '19',
#   'Total goalkeeping': '51',
#   'GK Diving': '6',
#   'GK Handling': '11',
#   'GK Kicking': '12',
#   'GK Positioning': '8',
#   'GK Reflexes': '14',
#   'Total stats': '1869',
#   'Base stats': '398',
#   'Weak foot': '3',
#   'Skill moves': '4',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'Low',
#   'International reputation': '1',
#   'Body type': 'Normal (185+)',
#   'Real face': 'Yes',
#   'Pace / Diving': '75',
#   'Shooting / Handling': '78',
#   'Passing / Kicking': '70',
#   'Dribbling / Reflexes': '81',
#   'Defending / Pace': '24',
#   'Physical / Positioning': '70',
#   'Traits': '',
#   'PlayStyles': 'Technical\u2003Flair\u2003First Touch',
#   'PlayStyles +': '',
#   'Number of playstyles': '3',
#   '': ''},
#  {'name': 'Vitor Roque ST RW LW',
#   'Age': '18',
#   'Overall rating': '76',
#   'Potential': '88',
#   'Team & Contract': 'FC Barcelona\n2024 ~ 2031',
#   'ID': '276589',
#   'Height': '172cm / 5\'8"',
#   'Weight': '78kg / 172lbs',
#   'foot': 'Right',
#   'Best overall': '78',
#   'Best position': 'ST',
#   'Growth': '12',
#   'Joined': 'Jan 1, 2024',
#   'Loan date end': 'N/A',
#   'Value': '€17.5M',
#   'Wage': '€44K',
#   'Release clause': '€39.4M',
#   'Total attacking': '335',
#   'Crossing': '62',
#   'Finishing': '82',
#   'Heading accuracy': '62',
#   'Short passing': '54',
#   'Volleys': '75',
#   'Total skill': '356',
#   'Dribbling': '83',
#   'Curve': '74',
#   'FK Accuracy': '70',
#   'Long passing': '52',
#   'Ball control': '77',
#   'Total movement': '406',
#   'Acceleration': '88',
#   'Sprint speed': '83',
#   'Agility': '85',
#   'Reactions': '70',
#   'Balance': '80',
#   'Total power': '377',
#   'Shot power': '80',
#   'Jumping': '83',
#   'Stamina': '65',
#   'Strength': '75',
#   'Long shots': '74',
#   'Total mentality': '257',
#   'Aggression': '28',
#   'Interceptions': '15',
#   'Att. Position': '80',
#   'Vision': '62',
#   'Penalties': '72',
#   'Composure': '74',
#   'Total defending': '44',
#   'Defensive awareness': '18',
#   'Standing tackle': '15',
#   'Sliding tackle': '11',
#   'Total goalkeeping': '54',
#   'GK Diving': '13',
#   'GK Handling': '14',
#   'GK Kicking': '12',
#   'GK Positioning': '6',
#   'GK Reflexes': '9',
#   'Total stats': '1829',
#   'Base stats': '387',
#   'Weak foot': '3',
#   'Skill moves': '4',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'High',
#   'International reputation': '1',
#   'Body type': 'Stocky (170-185)',
#   'Real face': 'No',
#   'Pace / Diving': '85',
#   'Shooting / Handling': '79',
#   'Passing / Kicking': '59',
#   'Dribbling / Reflexes': '80',
#   'Defending / Pace': '20',
#   'Physical / Positioning': '64',
#   'Traits': '',
#   'PlayStyles': 'Finesse Shot\u2003Power Shot\u2003Rapid\u2003Flair\u2003Quick Step',
#   'PlayStyles +': '',
#   'Number of playstyles': '5',
#   '': ''},
#  {'name': 'L. Yoro CB',
#   'Age': '17',
#   'Overall rating': '77+1',
#   'Potential': '86',
#   'Team & Contract': 'LOSC Lille\n2022 ~ 2025',
#   'ID': '269087',
#   'Height': '190cm / 6\'3"',
#   'Weight': '75kg / 165lbs',
#   'foot': 'Right',
#   'Best overall': '79',
#   'Best position': 'CB',
#   'Growth': '9',
#   'Joined': 'May 14, 2022',
#   'Loan date end': 'N/A',
#   'Value': '€20M',
#   'Wage': '€1K',
#   'Release clause': '€42M',
#   'Total attacking': '267',
#   'Crossing': '47',
#   'Finishing': '38',
#   'Heading accuracy': '74',
#   'Short passing': '73+1',
#   'Volleys': '35',
#   'Total skill': '250',
#   'Dribbling': '55',
#   'Curve': '37',
#   'FK Accuracy': '32',
#   'Long passing': '58',
#   'Ball control': '68',
#   'Total movement': '337',
#   'Acceleration': '65',
#   'Sprint speed': '79',
#   'Agility': '55+3',
#   'Reactions': '77+2',
#   'Balance': '61',
#   'Total power': '311',
#   'Shot power': '51',
#   'Jumping': '79',
#   'Stamina': '69+3',
#   'Strength': '75+1',
#   'Long shots': '37',
#   'Total mentality': '285',
#   'Aggression': '72+2',
#   'Interceptions': '77',
#   'Att. Position': '41',
#   'Vision': '55+2',
#   'Penalties': '40',
#   'Composure': '69',
#   'Total defending': '237',
#   'Defensive awareness': '77+2',
#   'Standing tackle': '81+1',
#   'Sliding tackle': '79+1',
#   'Total goalkeeping': '53',
#   'GK Diving': '13',
#   'GK Handling': '7',
#   'GK Kicking': '5',
#   'GK Positioning': '14',
#   'GK Reflexes': '14',
#   'Total stats': '1740',
#   'Base stats': '384',
#   'Weak foot': '3',
#   'Skill moves': '2',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Lean (185+)',
#   'Real face': 'No',
#   'Pace / Diving': '73',
#   'Shooting / Handling': '41',
#   'Passing / Kicking': '58',
#   'Dribbling / Reflexes': '61',
#   'Defending / Pace': '78',
#   'Physical / Positioning': '73',
#   'Traits': '',
#   'PlayStyles': '',
#   'PlayStyles +': '',
#   'Number of playstyles': '0',
#   '': ''},
#  {'name': 'W. Zaïre-Emery CM CDM',
#   'Age': '17',
#   'Overall rating': '80',
#   'Potential': '90',
#   'Team & Contract': 'Paris Saint Germain\n2022 ~ 2029',
#   'ID': '270673',
#   'Height': '178cm / 5\'10"',
#   'Weight': '68kg / 150lbs',
#   'foot': 'Right',
#   'Best overall': '82',
#   'Best position': 'CM',
#   'Growth': '10',
#   'Joined': 'Jul 15, 2022',
#   'Loan date end': 'N/A',
#   'Value': '€43.5M',
#   'Wage': '€11K',
#   'Release clause': '€89.2M',
#   'Total attacking': '329',
#   'Crossing': '66',
#   'Finishing': '66',
#   'Heading accuracy': '66',
#   'Short passing': '82',
#   'Volleys': '49',
#   'Total skill': '357',
#   'Dribbling': '78',
#   'Curve': '64',
#   'FK Accuracy': '53',
#   'Long passing': '81',
#   'Ball control': '81',
#   'Total movement': '395',
#   'Acceleration': '80',
#   'Sprint speed': '78',
#   'Agility': '74',
#   'Reactions': '79',
#   'Balance': '84',
#   'Total power': '384',
#   'Shot power': '76',
#   'Jumping': '80',
#   'Stamina': '84',
#   'Strength': '75',
#   'Long shots': '69',
#   'Total mentality': '369',
#   'Aggression': '76',
#   'Interceptions': '78',
#   'Att. Position': '76',
#   'Vision': '80',
#   'Penalties': '59',
#   'Composure': '77',
#   'Total defending': '224',
#   'Defensive awareness': '71',
#   'Standing tackle': '80',
#   'Sliding tackle': '73',
#   'Total goalkeeping': '55',
#   'GK Diving': '14',
#   'GK Handling': '11',
#   'GK Kicking': '7',
#   'GK Positioning': '8',
#   'GK Reflexes': '15',
#   'Total stats': '2113',
#   'Base stats': '455',
#   'Weak foot': '4',
#   'Skill moves': '3',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'High',
#   'International reputation': '1',
#   'Body type': 'Normal (170-185)',
#   'Real face': 'No',
#   'Pace / Diving': '79',
#   'Shooting / Handling': '68',
#   'Passing / Kicking': '76',
#   'Dribbling / Reflexes': '79',
#   'Defending / Pace': '75',
#   'Physical / Positioning': '78',
#   'Traits': '',
#   'PlayStyles': 'First Touch\u2003Press Proven\u2003Quick Step',
#   'PlayStyles +': '',
#   'Number of playstyles': '3',
#   '': ''},
#  {'name': 'Pau Cubarsí CB',
#   'Age': '16',
#   'Overall rating': '66+2',
#   'Potential': '85+2',
#   'Team & Contract': 'FC Barcelona\n2023 ~ 2026',
#   'ID': '278046',
#   'Height': '182cm / 6\'0"',
#   'Weight': '75kg / 165lbs',
#   'foot': 'Right',
#   'Best overall': '68',
#   'Best position': 'CB',
#   'Growth': '19',
#   'Joined': 'Jul 1, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€2M',
#   'Wage': '€1K',
#   'Release clause': '€5.4M',
#   'Total attacking': '199',
#   'Crossing': '26',
#   'Finishing': '22',
#   'Heading accuracy': '65',
#   'Short passing': '65+2',
#   'Volleys': '21',
#   'Total skill': '214',
#   'Dribbling': '46+3',
#   'Curve': '22',
#   'FK Accuracy': '25',
#   'Long passing': '56+2',
#   'Ball control': '65+2',
#   'Total movement': '326',
#   'Acceleration': '65+2',
#   'Sprint speed': '69+1',
#   'Agility': '65',
#   'Reactions': '65+1',
#   'Balance': '62',
#   'Total power': '244',
#   'Shot power': '32',
#   'Jumping': '68+1',
#   'Stamina': '68',
#   'Strength': '60',
#   'Long shots': '16',
#   'Total mentality': '223',
#   'Aggression': '63',
#   'Interceptions': '66+1',
#   'Att. Position': '22',
#   'Vision': '36+2',
#   'Penalties': '36',
#   'Composure': '61+2',
#   'Total defending': '202',
#   'Defensive awareness': '65+2',
#   'Standing tackle': '69+2',
#   'Sliding tackle': '68+2',
#   'Total goalkeeping': '51',
#   'GK Diving': '10',
#   'GK Handling': '6',
#   'GK Kicking': '14',
#   'GK Positioning': '7',
#   'GK Reflexes': '14',
#   'Total stats': '1459',
#   'Base stats': '322',
#   'Weak foot': '4',
#   'Skill moves': '2',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Lean (170-185)',
#   'Real face': 'No',
#   'Pace / Diving': '67',
#   'Shooting / Handling': '23',
#   'Passing / Kicking': '46',
#   'Dribbling / Reflexes': '56',
#   'Defending / Pace': '67',
#   'Physical / Positioning': '63',
#   'Traits': '',
#   'PlayStyles': '',
#   'PlayStyles +': '',
#   'Number of playstyles': '0',
#   '': ''},
#  {'name': 'F. Wirtz CAM',
#   'Age': '20',
#   'Overall rating': '87',
#   'Potential': '92',
#   'Team & Contract': 'Bayer 04 Leverkusen\n2020 ~ 2027',
#   'ID': '256630',
#   'Height': '177cm / 5\'10"',
#   'Weight': '71kg / 157lbs',
#   'foot': 'Right',
#   'Best overall': '89',
#   'Best position': 'CAM',
#   'Growth': '5',
#   'Joined': 'Jan 31, 2020',
#   'Loan date end': 'N/A',
#   'Value': '€118.5M',
#   'Wage': '€77K',
#   'Release clause': '€210.3M',
#   'Total attacking': '367',
#   'Crossing': '82',
#   'Finishing': '79',
#   'Heading accuracy': '42',
#   'Short passing': '90',
#   'Volleys': '74',
#   'Total skill': '407',
#   'Dribbling': '87',
#   'Curve': '80',
#   'FK Accuracy': '64',
#   'Long passing': '86',
#   'Ball control': '90',
#   'Total movement': '420',
#   'Acceleration': '81',
#   'Sprint speed': '80',
#   'Agility': '87',
#   'Reactions': '86',
#   'Balance': '86',
#   'Total power': '347',
#   'Shot power': '75',
#   'Jumping': '61',
#   'Stamina': '83',
#   'Strength': '53',
#   'Long shots': '75',
#   'Total mentality': '340',
#   'Aggression': '63',
#   'Interceptions': '44',
#   'Att. Position': '83',
#   'Vision': '90',
#   'Penalties': '60',
#   'Composure': '84',
#   'Total defending': '151',
#   'Defensive awareness': '58',
#   'Standing tackle': '49',
#   'Sliding tackle': '44',
#   'Total goalkeeping': '57',
#   'GK Diving': '14',
#   'GK Handling': '14',
#   'GK Kicking': '13',
#   'GK Positioning': '6',
#   'GK Reflexes': '10',
#   'Total stats': '2089',
#   'Base stats': '443',
#   'Weak foot': '4',
#   'Skill moves': '4',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '3',
#   'Body type': 'Normal (170-185)',
#   'Real face': 'Yes',
#   'Pace / Diving': '80',
#   'Shooting / Handling': '76',
#   'Passing / Kicking': '86',
#   'Dribbling / Reflexes': '88',
#   'Defending / Pace': '50',
#   'Physical / Positioning': '63',
#   'Traits': '',
#   'PlayStyles': 'Chip Shot\u2003Incisive Pass\u2003Technical\u2003Flair\u2003First Touch\u2003Trivela',
#   'PlayStyles +': '',
#   'Number of playstyles': '6',
#   '': ''},
#  {'name': 'J. Bellingham CAM CM',
#   'Age': '20',
#   'Overall rating': '88',
#   'Potential': '92',
#   'Team & Contract': 'Real Madrid\n2023 ~ 2029',
#   'ID': '252371',
#   'Height': '186cm / 6\'1"',
#   'Weight': '75kg / 165lbs',
#   'foot': 'Right',
#   'Best overall': '90',
#   'Best position': 'CAM',
#   'Growth': '4',
#   'Joined': 'Jul 1, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€128.5M',
#   'Wage': '€230K',
#   'Release clause': '€273.1M',
#   'Total attacking': '385',
#   'Crossing': '66',
#   'Finishing': '87',
#   'Heading accuracy': '69',
#   'Short passing': '89',
#   'Volleys': '74',
#   'Total skill': '391',
#   'Dribbling': '88',
#   'Curve': '73',
#   'FK Accuracy': '56',
#   'Long passing': '87',
#   'Ball control': '87',
#   'Total movement': '411',
#   'Acceleration': '81',
#   'Sprint speed': '80',
#   'Agility': '82',
#   'Reactions': '89',
#   'Balance': '79',
#   'Total power': '411',
#   'Shot power': '79',
#   'Jumping': '82+1',
#   'Stamina': '93',
#   'Strength': '77+2',
#   'Long shots': '80',
#   'Total mentality': '416',
#   'Aggression': '85',
#   'Interceptions': '82',
#   'Att. Position': '88',
#   'Vision': '87',
#   'Penalties': '74+10',
#   'Composure': '85',
#   'Total defending': '233',
#   'Defensive awareness': '77',
#   'Standing tackle': '79',
#   'Sliding tackle': '77',
#   'Total goalkeeping': '48',
#   'GK Diving': '14',
#   'GK Handling': '11',
#   'GK Kicking': '10',
#   'GK Positioning': '5',
#   'GK Reflexes': '8',
#   'Total stats': '2295',
#   'Base stats': '492',
#   'Weak foot': '4',
#   'Skill moves': '4',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'High',
#   'International reputation': '4',
#   'Body type': 'Normal (185+)',
#   'Real face': 'Yes',
#   'Pace / Diving': '80',
#   'Shooting / Handling': '83',
#   'Passing / Kicking': '81',
#   'Dribbling / Reflexes': '87',
#   'Defending / Pace': '78',
#   'Physical / Positioning': '83',
#   'Traits': '',
#   'PlayStyles': 'Intercept\u2003Slide Tackle\u2003Technical\u2003Flair',
#   'PlayStyles +': 'Relentless +',
#   'Number of playstyles': '5',
#   '': ''},
#  {'name': 'V. Gyökeres ST LW CF',
#   'Age': '25',
#   'Overall rating': '82',
#   'Potential': '87',
#   'Team & Contract': 'Sporting CP\n2023 ~ 2028',
#   'ID': '241651',
#   'Height': '187cm / 6\'2"',
#   'Weight': '90kg / 198lbs',
#   'foot': 'Right',
#   'Best overall': '84',
#   'Best position': 'ST',
#   'Growth': '5',
#   'Joined': 'Jul 13, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€45M',
#   'Wage': '€22K',
#   'Release clause': '€93.4M',
#   'Total attacking': '371',
#   'Crossing': '61',
#   'Finishing': '85',
#   'Heading accuracy': '78',
#   'Short passing': '73',
#   'Volleys': '74',
#   'Total skill': '342',
#   'Dribbling': '81',
#   'Curve': '70',
#   'FK Accuracy': '59',
#   'Long passing': '52',
#   'Ball control': '80',
#   'Total movement': '403',
#   'Acceleration': '85',
#   'Sprint speed': '88',
#   'Agility': '70',
#   'Reactions': '79',
#   'Balance': '81',
#   'Total power': '434',
#   'Shot power': '85',
#   'Jumping': '94',
#   'Stamina': '93',
#   'Strength': '90',
#   'Long shots': '72',
#   'Total mentality': '346',
#   'Aggression': '82',
#   'Interceptions': '28',
#   'Att. Position': '83',
#   'Vision': '74',
#   'Penalties': '79',
#   'Composure': '79',
#   'Total defending': '84',
#   'Defensive awareness': '34',
#   'Standing tackle': '34',
#   'Sliding tackle': '16',
#   'Total goalkeeping': '56',
#   'GK Diving': '10',
#   'GK Handling': '13',
#   'GK Kicking': '11',
#   'GK Positioning': '14',
#   'GK Reflexes': '8',
#   'Total stats': '2036',
#   'Base stats': '438',
#   'Weak foot': '4',
#   'Skill moves': '3',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Normal (185+)',
#   'Real face': 'Yes',
#   'Pace / Diving': '87',
#   'Shooting / Handling': '81',
#   'Passing / Kicking': '67',
#   'Dribbling / Reflexes': '79',
#   'Defending / Pace': '35',
#   'Physical / Positioning': '89',
#   'Traits': '',
#   'PlayStyles': 'Press Proven',
#   'PlayStyles +': '',
#   'Number of playstyles': '1',
#   '': ''},
#  {'name': 'R. Højlund ST',
#   'Age': '20',
#   'Overall rating': '78',
#   'Potential': '89',
#   'Team & Contract': 'Manchester United\n2023 ~ 2028',
#   'ID': '259399',
#   'Height': '191cm / 6\'3"',
#   'Weight': '79kg / 174lbs',
#   'foot': 'Left',
#   'Best overall': '80',
#   'Best position': 'ST',
#   'Growth': '11',
#   'Joined': 'Aug 5, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€31M',
#   'Wage': '€82K',
#   'Release clause': '€65.1M',
#   'Total attacking': '326',
#   'Crossing': '38',
#   'Finishing': '78',
#   'Heading accuracy': '70',
#   'Short passing': '72',
#   'Volleys': '68',
#   'Total skill': '306',
#   'Dribbling': '76',
#   'Curve': '58',
#   'FK Accuracy': '48',
#   'Long passing': '49',
#   'Ball control': '75',
#   'Total movement': '378',
#   'Acceleration': '82',
#   'Sprint speed': '86',
#   'Agility': '69',
#   'Reactions': '78',
#   'Balance': '63',
#   'Total power': '405',
#   'Shot power': '83',
#   'Jumping': '88',
#   'Stamina': '78',
#   'Strength': '86',
#   'Long shots': '70',
#   'Total mentality': '325',
#   'Aggression': '82',
#   'Interceptions': '28',
#   'Att. Position': '80',
#   'Vision': '65',
#   'Penalties': '70',
#   'Composure': '75',
#   'Total defending': '79',
#   'Defensive awareness': '32',
#   'Standing tackle': '28',
#   'Sliding tackle': '19',
#   'Total goalkeeping': '50',
#   'GK Diving': '12',
#   'GK Handling': '8',
#   'GK Kicking': '9',
#   'GK Positioning': '14',
#   'GK Reflexes': '7',
#   'Total stats': '1869',
#   'Base stats': '409',
#   'Weak foot': '3',
# ...
#   'Total stats': '1897',
#   'Base stats': '409',
#   'Weak foot': '5',
#   'Skill moves': '4',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Normal (170-)',
#   'Real face': 'Yes',
#   'Pace / Diving': '85',
#   'Shooting / Handling': '74',
#   'Passing / Kicking': '78',
#   'Dribbling / Reflexes': '85',
#   'Defending / Pace': '31',
#   'Physical / Positioning': '56',
#   'Traits': '',
#   'PlayStyles': 'Technical\u2003Flair\u2003First Touch',
#   'PlayStyles +': '',
#   '': ''},
#  {'name': 'K. Mbappé ST LW',
#   'Age': '24',
#   'Overall rating': '91',
#   'Potential': '94',
#   'Team & Contract': 'Paris Saint Germain\n2018 ~ 2024',
#   'ID': '231747',
#   'Height': '182cm / 6\'0"',
#   'Weight': '75kg / 165lbs',
#   'foot': 'Right',
#   'Best overall': '93',
#   'Best position': 'ST',
#   'Growth': '3',
#   'Joined': 'Jul 1, 2018',
#   'Loan date end': 'N/A',
#   'Value': '€181.5M',
#   'Wage': '€230K',
#   'Release clause': '€349.4M',
#   'Total attacking': '415',
#   'Crossing': '78',
#   'Finishing': '94',
#   'Heading accuracy': '73',
#   'Short passing': '86',
#   'Volleys': '84',
#   'Total skill': '405',
#   'Dribbling': '93',
#   'Curve': '80',
#   'FK Accuracy': '69',
#   'Long passing': '71',
#   'Ball control': '92',
#   'Total movement': '462',
#   'Acceleration': '97',
#   'Sprint speed': '97',
#   'Agility': '93',
#   'Reactions': '93',
#   'Balance': '82',
#   'Total power': '426',
#   'Shot power': '90',
#   'Jumping': '88',
#   'Stamina': '88',
#   'Strength': '77',
#   'Long shots': '83',
#   'Total mentality': '362',
#   'Aggression': '64',
#   'Interceptions': '38',
#   'Att. Position': '93',
#   'Vision': '83',
#   'Penalties': '84',
#   'Composure': '88',
#   'Total defending': '92',
#   'Defensive awareness': '26',
#   'Standing tackle': '34',
#   'Sliding tackle': '32',
#   'Total goalkeeping': '42',
#   'GK Diving': '13',
#   'GK Handling': '5',
#   'GK Kicking': '7',
#   'GK Positioning': '11',
#   'GK Reflexes': '6',
#   'Total stats': '2204',
#   'Base stats': '473',
#   'Weak foot': '4',
#   'Skill moves': '5',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Low',
#   'International reputation': '5',
#   'Body type': 'Unique',
#   'Real face': 'Yes',
#   'Pace / Diving': '97',
#   'Shooting / Handling': '90',
#   'Passing / Kicking': '80',
#   'Dribbling / Reflexes': '92',
#   'Defending / Pace': '36',
#   'Physical / Positioning': '78',
#   'Traits': '',
#   'PlayStyles': 'Finesse Shot\u2003Rapid\u2003Flair\u2003Trivela\u2003Acrobatic',
#   'PlayStyles +': 'Quick Step +',
#   '': ''},
#  {'name': 'M. Caicedo CDM CM',
#   'Age': '21',
#   'Overall rating': '80+1',
#   'Potential': '86',
#   'Team & Contract': 'Chelsea\n2023 ~ 2031',
#   'ID': '256079',
#   'Height': '178cm / 5\'10"',
#   'Weight': '73kg / 161lbs',
#   'foot': 'Right',
#   'Best overall': '81',
#   'Best position': 'CDM',
#   'Growth': '6',
#   'Joined': 'Aug 14, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€31M',
#   'Wage': '€71K',
#   'Release clause': '€65.1M',
#   'Total attacking': '310',
#   'Crossing': '57+1',
#   'Finishing': '57',
#   'Heading accuracy': '58',
#   'Short passing': '83',
#   'Volleys': '55',
#   'Total skill': '350',
#   'Dribbling': '74',
#   'Curve': '63+2',
#   'FK Accuracy': '55',
#   'Long passing': '77+1',
#   'Ball control': '81',
#   'Total movement': '373',
#   'Acceleration': '77',
#   'Sprint speed': '70',
#   'Agility': '73',
#   'Reactions': '78+2',
#   'Balance': '75',
#   'Total power': '368',
#   'Shot power': '71',
#   'Jumping': '74',
#   'Stamina': '83+1',
#   'Strength': '70',
#   'Long shots': '70',
#   'Total mentality': '350',
#   'Aggression': '78+1',
#   'Interceptions': '80+2',
#   'Att. Position': '62',
#   'Vision': '75+1',
#   'Penalties': '55',
#   'Composure': '79',
#   'Total defending': '237',
#   'Defensive awareness': '77+2',
#   'Standing tackle': '81',
#   'Sliding tackle': '79+1',
#   'Total goalkeeping': '56',
#   'GK Diving': '15',
#   'GK Handling': '6',
#   'GK Kicking': '13',
#   'GK Positioning': '9',
#   'GK Reflexes': '13',
#   'Total stats': '2044',
#   'Base stats': '437',
#   'Weak foot': '3',
#   'Skill moves': '3',
#   'Attacking work rate': 'Medium',
#   'Defensive work rate': 'High',
#   'International reputation': '2',
#   'Body type': 'Normal (170-185)',
#   'Real face': 'Yes',
#   'Pace / Diving': '73',
#   'Shooting / Handling': '62',
#   'Passing / Kicking': '73',
#   'Dribbling / Reflexes': '77',
#   'Defending / Pace': '77',
#   'Physical / Positioning': '75',
#   'Traits': '',
#   'PlayStyles': 'Pinged Pass\u2003Tiki Taka\u2003Intercept\u2003Anticipate\u2003Slide Tackle\u2003Relentless',
#   'PlayStyles +': '',
#   '': ''},
#  {'name': 'T. Baldanzi CAM CF',
#   'Age': '20',
#   'Overall rating': '77',
#   'Potential': '87',
#   'Team & Contract': 'Roma\n2024 ~ 2028',
#   'ID': '269312',
#   'Height': '170cm / 5\'7"',
#   'Weight': '63kg / 139lbs',
#   'foot': 'Left',
#   'Best overall': '79',
#   'Best position': 'CAM',
#   'Growth': '10',
#   'Joined': 'Feb 1, 2024',
#   'Loan date end': 'N/A',
#   'Value': '€23M',
#   'Wage': '€41K',
#   'Release clause': '€43.7M',
#   'Total attacking': '329',
#   'Crossing': '68',
#   'Finishing': '69',
#   'Heading accuracy': '44',
#   'Short passing': '78',
#   'Volleys': '70',
#   'Total skill': '369',
#   'Dribbling': '82',
#   'Curve': '75',
#   'FK Accuracy': '64',
#   'Long passing': '68',
#   'Ball control': '80',
#   'Total movement': '398',
#   'Acceleration': '79',
#   'Sprint speed': '78',
#   'Agility': '83',
#   'Reactions': '70',
#   'Balance': '88',
#   'Total power': '311',
#   'Shot power': '77',
#   'Jumping': '52',
#   'Stamina': '68',
#   'Strength': '40',
#   'Long shots': '74',
#   'Total mentality': '302',
#   'Aggression': '53',
#   'Interceptions': '33',
#   'Att. Position': '79',
#   'Vision': '79',
#   'Penalties': '58',
#   'Composure': '69',
#   'Total defending': '131',
#   'Defensive awareness': '42',
#   'Standing tackle': '41',
#   'Sliding tackle': '48',
#   'Total goalkeeping': '50',
#   'GK Diving': '12',
#   'GK Handling': '9',
#   'GK Kicking': '10',
#   'GK Positioning': '12',
#   'GK Reflexes': '7',
#   'Total stats': '1890',
#   'Base stats': '396',
#   'Weak foot': '3',
#   'Skill moves': '3',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Normal (170-)',
#   'Real face': 'Yes',
#   'Pace / Diving': '78',
#   'Shooting / Handling': '72',
#   'Passing / Kicking': '74',
#   'Dribbling / Reflexes': '81',
#   'Defending / Pace': '41',
#   'Physical / Positioning': '50',
#   'Traits': '',
#   'PlayStyles': 'Finesse Shot\u2003Technical\u2003Flair',
#   'PlayStyles +': '',
#   '': ''},
#  {'name': 'Lucas Beraldo CB LB',
#   'Age': '19',
#   'Overall rating': '75',
#   'Potential': '86',
#   'Team & Contract': 'Paris Saint Germain\n2024 ~ 2028',
#   'ID': '279709',
#   'Height': '182cm / 6\'0"',
#   'Weight': '78kg / 172lbs',
#   'foot': 'Left',
#   'Best overall': '77',
#   'Best position': 'CB',
#   'Growth': '11',
#   'Joined': 'Jan 1, 2024',
#   'Loan date end': 'N/A',
#   'Value': '€11.5M',
#   'Wage': '€28K',
#   'Release clause': '€23.6M',
#   'Total attacking': '263',
#   'Crossing': '53',
#   'Finishing': '34',
#   'Heading accuracy': '69',
#   'Short passing': '77',
#   'Volleys': '30',
#   'Total skill': '299',
#   'Dribbling': '66',
#   'Curve': '58',
#   'FK Accuracy': '34',
#   'Long passing': '71',
#   'Ball control': '70',
#   'Total movement': '322',
#   'Acceleration': '64',
#   'Sprint speed': '73',
#   'Agility': '57',
#   'Reactions': '70',
#   'Balance': '58',
#   'Total power': '300',
#   'Shot power': '56',
#   'Jumping': '75',
#   'Stamina': '63',
#   'Strength': '75',
#   'Long shots': '31',
#   'Total mentality': '294',
#   'Aggression': '80',
#   'Interceptions': '74',
#   'Att. Position': '35',
#   'Vision': '59',
#   'Penalties': '46',
#   'Composure': '68',
#   'Total defending': '227',
#   'Defensive awareness': '72',
#   'Standing tackle': '78',
#   'Sliding tackle': '77',
#   'Total goalkeeping': '60',
#   'GK Diving': '11',
#   'GK Handling': '14',
#   'GK Kicking': '15',
#   'GK Positioning': '12',
#   'GK Reflexes': '8',
#   'Total stats': '1765',
#   'Base stats': '385',
#   'Weak foot': '2',
#   'Skill moves': '2',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Normal (170-185)',
#   'Real face': 'No',
#   'Pace / Diving': '69',
#   'Shooting / Handling': '38',
#   'Passing / Kicking': '65',
#   'Dribbling / Reflexes': '66',
#   'Defending / Pace': '74',
#   'Physical / Positioning': '73',
#   'Traits': '',
#   'PlayStyles': 'Pinged Pass\u2003Slide Tackle',
#   'PlayStyles +': '',
#   '': ''},
#  {'name': 'Cristiano Ronaldo ST',
#   'Age': '38',
#   'Overall rating': '86',
#   'Potential': '86',
#   'Team & Contract': 'Al Nassr\n2023 ~ 2025',
#   'ID': '20801',
#   'Height': '187cm / 6\'2"',
#   'Weight': '85kg / 187lbs',
#   'foot': 'Right',
#   'Best overall': '86',
#   'Best position': 'ST',
#   'Growth': '0',
#   'Joined': 'Jan 1, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€23M',
#   'Wage': '€66K',
#   'Release clause': '€36.8M',
#   'Total attacking': '414',
#   'Crossing': '78',
#   'Finishing': '87',
#   'Heading accuracy': '87',
#   'Short passing': '79',
#   'Volleys': '83',
#   'Total skill': '388',
#   'Dribbling': '77',
#   'Curve': '79',
#   'FK Accuracy': '76',
#   'Long passing': '70',
#   'Ball control': '86',
#   'Total movement': '377',
#   'Acceleration': '73',
#   'Sprint speed': '80',
#   'Agility': '76',
#   'Reactions': '87',
#   'Balance': '61',
#   'Total power': '426',
#   'Shot power': '92',
#   'Jumping': '93',
#   'Stamina': '80',
#   'Strength': '76',
#   'Long shots': '85',
#   'Total mentality': '349',
#   'Aggression': '62',
#   'Interceptions': '29',
#   'Att. Position': '90',
#   'Vision': '78',
#   'Penalties': '90',
#   'Composure': '92',
#   'Total defending': '80',
#   'Defensive awareness': '24',
#   'Standing tackle': '32',
#   'Sliding tackle': '24',
#   'Total goalkeeping': '58',
#   'GK Diving': '7',
#   'GK Handling': '11',
#   'GK Kicking': '15',
#   'GK Positioning': '14',
#   'GK Reflexes': '11',
#   'Total stats': '2092',
#   'Base stats': '431',
#   'Weak foot': '4',
#   'Skill moves': '5',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Low',
#   'International reputation': '5',
#   'Body type': 'Unique',
#   'Real face': 'Yes',
#   'Pace / Diving': '77',
#   'Shooting / Handling': '88',
#   'Passing / Kicking': '77',
#   'Dribbling / Reflexes': '80',
#   'Defending / Pace': '34',
#   'Physical / Positioning': '75',
#   'Traits': '',
#   'PlayStyles': 'Power Header\u2003Flair\u2003Trickster\u2003Trivela\u2003Acrobatic\u2003Aerial',
#   'PlayStyles +': 'Power Shot +',
#   '': ''},
#  {'name': 'I. Maatsen LB',
#   'Age': '21',
#   'Overall rating': '77+1',
#   'Potential': '85+1',
#   'Team & Contract': 'Borussia Dortmund\nJun 30, 2024 On loan',
#   'ID': '248465',
#   'Height': '178cm / 5\'10"',
#   'Weight': '63kg / 139lbs',
#   'foot': 'Left',
#   'Best overall': '78',
#   'Best position': 'LWB',
#   'Growth': '8',
#   'Joined': 'Sep 25, 2018',
#   'Loan date end': 'Jun 30, 2024',
#   'Value': '€22.5M',
#   'Wage': '€57K',
#   'Release clause': '€0',
#   'Total attacking': '321',
#   'Crossing': '75+1',
#   'Finishing': '59+3',
#   'Heading accuracy': '58',
#   'Short passing': '77+2',
#   'Volleys': '52+6',
#   'Total skill': '351',
#   'Dribbling': '78+3',
#   'Curve': '67',
#   'FK Accuracy': '62',
#   'Long passing': '66+2',
#   'Ball control': '78+1',
#   'Total movement': '418',
#   'Acceleration': '87',
#   'Sprint speed': '87',
#   'Agility': '84',
#   'Reactions': '74',
#   'Balance': '86',
#   'Total power': '324',
#   'Shot power': '65',
#   'Jumping': '70',
#   'Stamina': '77',
#   'Strength': '53',
#   'Long shots': '59',
#   'Total mentality': '325',
#   'Aggression': '74',
#   'Interceptions': '71+1',
#   'Att. Position': '67+1',
#   'Vision': '68+1',
#   'Penalties': '45',
#   'Composure': '71+1',
#   'Total defending': '217',
#   'Defensive awareness': '70+2',
#   'Standing tackle': '72',
#   'Sliding tackle': '75+1',
#   'Total goalkeeping': '55',
#   'GK Diving': '9',
#   'GK Handling': '10',
#   'GK Kicking': '12',
#   'GK Positioning': '15',
#   'GK Reflexes': '9',
#   'Total stats': '2011',
#   'Base stats': '431',
#   'Weak foot': '4',
#   'Skill moves': '3',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '1',
#   'Body type': 'Lean (170-185)',
#   'Real face': 'No',
#   'Pace / Diving': '87',
#   'Shooting / Handling': '60',
#   'Passing / Kicking': '72',
#   'Dribbling / Reflexes': '78',
#   'Defending / Pace': '70',
#   'Physical / Positioning': '64',
#   'Traits': '',
#   'PlayStyles': 'Slide Tackle\u2003Rapid',
#   'PlayStyles +': '',
#   '': ''},
#  {'name': 'J. Gvardiol CB LB',
#   'Age': '21',
#   'Overall rating': '82',
#   'Potential': '88',
#   'Team & Contract': 'Manchester City\n2023 ~ 2028',
#   'ID': '251517',
#   'Height': '185cm / 6\'1"',
#   'Weight': '80kg / 176lbs',
#   'foot': 'Left',
#   'Best overall': '85',
#   'Best position': 'CB',
#   'Growth': '6',
#   'Joined': 'Aug 5, 2023',
#   'Loan date end': 'N/A',
#   'Value': '€44.5M',
#   'Wage': '€95K',
#   'Release clause': '€91.2M',
#   'Total attacking': '330',
#   'Crossing': '68',
#   'Finishing': '50',
#   'Heading accuracy': '78',
#   'Short passing': '80',
#   'Volleys': '54',
#   'Total skill': '358',
#   'Dribbling': '78',
#   'Curve': '67',
#   'FK Accuracy': '59',
#   'Long passing': '76',
#   'Ball control': '78',
#   'Total movement': '376',
#   'Acceleration': '80',
#   'Sprint speed': '79',
#   'Agility': '71',
#   'Reactions': '79',
#   'Balance': '67',
#   'Total power': '399',
#   'Shot power': '79',
#   'Jumping': '90',
#   'Stamina': '79',
#   'Strength': '83',
#   'Long shots': '68',
#   'Total mentality': '352',
#   'Aggression': '86',
#   'Interceptions': '82',
#   'Att. Position': '58',
#   'Vision': '65',
#   'Penalties': '61',
#   'Composure': '75',
#   'Total defending': '249',
#   'Defensive awareness': '81',
#   'Standing tackle': '84',
#   'Sliding tackle': '84',
#   'Total goalkeeping': '39',
#   'GK Diving': '5',
#   'GK Handling': '8',
#   'GK Kicking': '6',
#   'GK Positioning': '9',
#   'GK Reflexes': '11',
#   'Total stats': '2103',
#   'Base stats': '454',
#   'Weak foot': '4',
#   'Skill moves': '3',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'High',
#   'International reputation': '3',
#   'Body type': 'Normal (185+)',
#   'Real face': 'Yes',
#   'Pace / Diving': '79',
#   'Shooting / Handling': '61',
#   'Passing / Kicking': '72',
#   'Dribbling / Reflexes': '77',
#   'Defending / Pace': '82',
#   'Physical / Positioning': '83',
#   'Traits': '',
#   'PlayStyles': 'Power Header\u2003Pinged Pass\u2003Long Ball Pass\u2003Jockey',
#   'PlayStyles +': 'Block +',
#   '': ''},
#  {'name': 'V. Osimhen ST',
#   'Age': '24',
#   'Overall rating': '87',
#   'Potential': '90',
#   'Team & Contract': 'Napoli\n2020 ~ 2025',
#   'ID': '232293',
#   'Height': '186cm / 6\'1"',
#   'Weight': '77kg / 170lbs',
#   'foot': 'Right',
#   'Best overall': '89',
#   'Best position': 'ST',
#   'Growth': '3',
#   'Joined': 'Sep 1, 2020',
#   'Loan date end': 'N/A',
#   'Value': '€110M',
#   'Wage': '€100K',
#   'Release clause': '€195.3M',
#   'Total attacking': '391',
#   'Crossing': '62',
#   'Finishing': '91',
#   'Heading accuracy': '84',
#   'Short passing': '71',
#   'Volleys': '83',
#   'Total skill': '336',
#   'Dribbling': '83',
#   'Curve': '63',
#   'FK Accuracy': '52',
#   'Long passing': '54',
#   'Ball control': '84',
#   'Total movement': '414',
#   'Acceleration': '87',
#   'Sprint speed': '92',
#   'Agility': '78',
#   'Reactions': '89',
#   'Balance': '68',
#   'Total power': '424',
#   'Shot power': '86',
#   'Jumping': '94',
#   'Stamina': '81',
#   'Strength': '86',
#   'Long shots': '77',
#   'Total mentality': '337',
#   'Aggression': '68',
#   'Interceptions': '34',
#   'Att. Position': '90',
#   'Vision': '70',
#   'Penalties': '75',
#   'Composure': '80',
#   'Total defending': '103',
#   'Defensive awareness': '36',
#   'Standing tackle': '45',
#   'Sliding tackle': '22',
#   'Total goalkeeping': '53',
#   'GK Diving': '14',
#   'GK Handling': '14',
#   'GK Kicking': '10',
#   'GK Positioning': '9',
#   'GK Reflexes': '6',
#   'Total stats': '2058',
#   'Base stats': '447',
#   'Weak foot': '4',
#   'Skill moves': '3',
#   'Attacking work rate': 'High',
#   'Defensive work rate': 'Medium',
#   'International reputation': '3',
#   'Body type': 'Lean (185+)',
#   'Real face': 'Yes',
#   'Pace / Diving': '90',
#   'Shooting / Handling': '86',
#   'Passing / Kicking': '65',
#   'Dribbling / Reflexes': '82',
#   'Defending / Pace': '42',
#   'Physical / Positioning': '82',
#   'Traits': '',
#   'PlayStyles': 'Chip Shot\u2003Power Header\u2003Rapid\u2003Acrobatic',
#   'PlayStyles +': '',
#   '': ''}]

# %%
df = pd.DataFrame(players)

# %%
df['Value']
# Out:
# 0       €8.5M
# 1        €12M
# 2       €4.7M
# 3          €0
# 4      €39.5M
#         ...
# 115    €11.5M
# 116      €23M
# 117    €22.5M
# 118    €44.5M
# 119     €110M
# Name: Value, Length: 120, dtype: object

# %%
df.to_csv('players_new.csv', index=False)

# %%
df.head()
# Out:
#                      name Age Overall rating Potential  \
# 0       A. Wharton CDM CM  19             74        85
# 1  Gabriel Sara CM CDM RM  24             76        82
# 2       K. Páez CAM CF RW  16             71        87
# 3           10 M. Dabo LF  23             56        65
# 4     C. Palmer RM RW CAM  21             79        87
#
#                         Team & Contract      ID         Height         Weight  \
# 0           Crystal Palace\n2024 ~ 2029  259240   182cm / 6'0"  70kg / 154lbs
# 1             Norwich City\n2022 ~ 2026  270571  177cm / 5'10"  79kg / 174lbs
# 2  Independiente del Valle\n2023 ~ 2025  274559  177cm / 5'10"  71kg / 157lbs
# 3                         Senegal\nFree  177703   186cm / 6'1"  77kg / 170lbs
# 4                  Chelsea\n2023 ~ 2030  257534   189cm / 6'2"  74kg / 163lbs
#
#    foot Best overall  ... Shooting / Handling Passing / Kicking  \
# 0  Left           76  ...                  61                75
# 1  Left           78  ...                  74                77
# 2  Left           73  ...                  66                69
# 3  Left           59  ...                  56                41
# 4  Left           82  ...                  77                77
#
#   Dribbling / Reflexes Defending / Pace Physical / Positioning Traits  \
# 0                   76               68                     70
# 1                   75               59                     80
# 2                   72               43                     52
# 3                   57               25                     49
# 4                   81               48                     62
#
#                                     PlayStyles PlayStyles +  \
# 0      Incisive Pass Slide Tackle Press Proven
# 1                             Power Shot Flair
# 2  Pinged Pass Technical First Touch Trickster
# 3
# 4                                    Technical
#
#   Number of playstyles
# 0                    3
# 1                    2
# 2                    4
# 3                    0
# 4                    1
#
# [5 rows x 78 columns]
